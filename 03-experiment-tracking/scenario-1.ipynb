# %% [markdown]
# ## Scenario 1: A single data scientist participating in an ML competition
#
# This scenario demonstrates how an individual data scientist can use MLflow to track machine learning experiments on their local machine. This is a common setup for solo projects, hackathons, or competitions where collaboration and remote access are not required.
#
# ### MLflow setup overview
# - **Tracking server:** Not used (runs locally, no remote server)
# - **Backend store:** Local filesystem (stores experiment metadata in the `mlruns/` folder)
# - **Artifacts store:** Local filesystem (stores model files and other artifacts in the same `mlruns/` folder)
#
# With this setup, all experiment runs, parameters, metrics, and artifacts are saved locally. You can explore and compare your experiments using the MLflow UI.
#
# ### How to use the MLflow UI
# - You can launch the MLflow UI by running `mlflow ui` in your terminal, or by running the provided code cell in this notebook.
# - The UI will be available at [http://localhost:5000](http://localhost:5000).
# - Use the UI to browse experiments, compare runs, and inspect logged models and artifacts.
#
# > **Tip:** This local setup is ideal for learning and prototyping. For team projects or production, you would typically use a remote tracking server and a more robust backend (e.g., a database and cloud storage).

# %%
# %pip install mlflow
import mlflow
# Out:
# Collecting mlflowNote: you may need to restart the kernel to use updated packages.
#
#   Using cached mlflow-3.10.0-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-skinny==3.10.0 (from mlflow)
#   Using cached mlflow_skinny-3.10.0-py3-none-any.whl.metadata (32 kB)
# Collecting mlflow-tracing==3.10.0 (from mlflow)
#   Using cached mlflow_tracing-3.10.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Using cached flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: Flask<4 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow) (3.1.0)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Using cached alembic-1.18.4-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: cryptography<47,>=43.0.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow) (44.0.1)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting huey<3,>=2.5.4 (from mlflow)
#   Using cached huey-2.6.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: matplotlib<4 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow) (3.10.8)
# Requirement already satisfied: numpy<3 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow) (2.4.2)
# Collecting pandas<3 (from mlflow)
#   Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: pyarrow<24,>=4.0.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow) (19.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow) (1.8.0)
# Requirement already satisfied: scipy<2 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow) (1.17.0)
# Collecting skops<1 (from mlflow)
#   Using cached skops-0.13.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow) (2.0.39)
# Collecting waitress<4 (from mlflow)
#   Using cached waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools<8,>=5.0.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow-skinny==3.10.0->mlflow) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow-skinny==3.10.0->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow-skinny==3.10.0->mlflow) (3.0.0)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached databricks_sdk-0.96.0-py3-none-any.whl.metadata (40 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached fastapi-0.135.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow-skinny==3.10.0->mlflow) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow-skinny==3.10.0->mlflow) (8.5.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached opentelemetry_proto-1.39.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<27 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow-skinny==3.10.0->mlflow) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow-skinny==3.10.0->mlflow) (5.29.3)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow-skinny==3.10.0->mlflow) (2.10.3)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow-skinny==3.10.0->mlflow) (1.1.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow-skinny==3.10.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow-skinny==3.10.0->mlflow) (2.32.3)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from mlflow-skinny==3.10.0->mlflow) (4.15.0)
# Collecting uvicorn<1 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached uvicorn-0.41.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: colorama in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.10.0->mlflow) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from cryptography<47,>=43.0.0->mlflow) (1.17.1)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.0->mlflow)
#   Using cached google_auth-2.48.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached protobuf-6.33.5-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: pywin32>=304 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (308)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Collecting starlette>=0.46.0 (from fastapi<1->mlflow-skinny==3.10.0->mlflow)
#   Using cached starlette-0.52.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting typing-inspection>=0.4.2 (from fastapi<1->mlflow-skinny==3.10.0->mlflow)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.10.0->mlflow)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.10.0->mlflow) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.10.0->mlflow) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.0->mlflow) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.0->mlflow)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.10.0->mlflow) (3.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.2.0)
# Collecting opentelemetry-semantic-conventions==0.60b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.10.0->mlflow)
#   Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.10.0->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.10.0->mlflow) (2.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.10.0->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.10.0->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.10.0->mlflow) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.0->mlflow) (0.4.8)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Collecting prettytable>=3.9 (from skops<1->mlflow)
#   Using cached prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: h11>=0.8 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from uvicorn<1->mlflow-skinny==3.10.0->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from cffi>=1.12->cryptography<47,>=43.0.0->mlflow) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from Jinja2>=3.1.2->Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: wcwidth in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from prettytable>=3.9->skops<1->mlflow) (0.2.5)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from starlette>=0.46.0->fastapi<1->mlflow-skinny==3.10.0->mlflow) (4.7.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\administrador.5198wortenamo\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi<1->mlflow-skinny==3.10.0->mlflow) (1.3.0)
# Using cached mlflow-3.10.0-py3-none-any.whl (10.2 MB)
# Using cached mlflow_skinny-3.10.0-py3-none-any.whl (3.0 MB)
# Using cached mlflow_tracing-3.10.0-py3-none-any.whl (1.5 MB)
# Using cached alembic-1.18.4-py3-none-any.whl (263 kB)
# Using cached databricks_sdk-0.96.0-py3-none-any.whl (813 kB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.135.1-py3-none-any.whl (116 kB)
# Using cached flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Using cached google_auth-2.48.0-py3-none-any.whl (236 kB)
# Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Using cached graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached huey-2.6.0-py3-none-any.whl (76 kB)
# Using cached opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
# Using cached opentelemetry_proto-1.39.1-py3-none-any.whl (72 kB)
# Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
# Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
# Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------------------------- -------------- 7.1/11.0 MB 34.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 27.0 MB/s eta 0:00:00
# Using cached protobuf-6.33.5-cp310-abi3-win_amd64.whl (437 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached skops-0.13.0-py3-none-any.whl (131 kB)
# Using cached sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Using cached uvicorn-0.41.0-py3-none-any.whl (68 kB)
# Using cached waitress-3.0.2-py3-none-any.whl (56 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached prettytable-3.17.0-py3-none-any.whl (34 kB)
# Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached mako-1.3.10-py3-none-any.whl (78 kB)
# Installing collected packages: huey, waitress, typing-inspection, sqlparse, rsa, protobuf, prettytable, Mako, graphql-core, annotated-doc, uvicorn, starlette, pandas, opentelemetry-proto, opentelemetry-api, graphql-relay, docker, alembic, skops, opentelemetry-semantic-conventions, graphene, google-auth, Flask-CORS, fastapi, opentelemetry-sdk, databricks-sdk, mlflow-tracing, mlflow-skinny, mlflow
#
#    ----------------------------------------  0/29 [huey]
#    - --------------------------------------  1/29 [waitress]
#    ---- -----------------------------------  3/29 [sqlparse]
#   Attempting uninstall: protobuf
#    ---- -----------------------------------  3/29 [sqlparse]
#    ------ ---------------------------------  5/29 [protobuf]
#     Found existing installation: protobuf 5.29.3
#    ------ ---------------------------------  5/29 [protobuf]
#     Uninstalling protobuf-5.29.3:
#    ------ ---------------------------------  5/29 [protobuf]
#       Successfully uninstalled protobuf-5.29.3
#    ------ ---------------------------------  5/29 [protobuf]
#    ------ ---------------------------------  5/29 [protobuf]
#    ------ ---------------------------------  5/29 [protobuf]
#    ------ ---------------------------------  5/29 [protobuf]
#    --------- ------------------------------  7/29 [Mako]
#    --------- ------------------------------  7/29 [Mako]
#    ----------- ----------------------------  8/29 [graphql-core]
#    ----------- ----------------------------  8/29 [graphql-core]
#    ----------- ----------------------------  8/29 [graphql-core]
#    ----------- ----------------------------  8/29 [graphql-core]
#    ----------- ----------------------------  8/29 [graphql-core]
#    ------------- -------------------------- 10/29 [uvicorn]
#    --------------- ------------------------ 11/29 [starlette]
#    --------------- ------------------------ 11/29 [starlette]
#   Attempting uninstall: pandas
#    --------------- ------------------------ 11/29 [starlette]
#     Found existing installation: pandas 3.0.0
#    --------------- ------------------------ 11/29 [starlette]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#     Uninstalling pandas-3.0.0:
#    ---------------- ----------------------- 12/29 [pandas]
#       Successfully uninstalled pandas-3.0.0
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ---------------- ----------------------- 12/29 [pandas]
#    ----------------- ---------------------- 13/29 [opentelemetry-proto]
#    ------------------- -------------------- 14/29 [opentelemetry-api]
#    -------------------- ------------------- 15/29 [graphql-relay]
#    ---------------------- ----------------- 16/29 [docker]
#    ---------------------- ----------------- 16/29 [docker]
#    ----------------------- ---------------- 17/29 [alembic]
#    ----------------------- ---------------- 17/29 [alembic]
#    ----------------------- ---------------- 17/29 [alembic]
#    ----------------------- ---------------- 17/29 [alembic]
#    ------------------------ --------------- 18/29 [skops]
#    ------------------------ --------------- 18/29 [skops]
#    --------------------- ----------- 19/29 [opentelemetry-semantic-conventions]
#    --------------------- ----------- 19/29 [opentelemetry-semantic-conventions]
#    --------------------- ----------- 19/29 [opentelemetry-semantic-conventions]
#    --------------------------- ------------ 20/29 [graphene]
#    --------------------------- ------------ 20/29 [graphene]
#    --------------------------- ------------ 20/29 [graphene]
#    ---------------------------- ----------- 21/29 [google-auth]
#    ---------------------------- ----------- 21/29 [google-auth]
#    ---------------------------- ----------- 21/29 [google-auth]
#    ------------------------------- -------- 23/29 [fastapi]
#    ------------------------------- -------- 23/29 [fastapi]
#    --------------------------------- ------ 24/29 [opentelemetry-sdk]
#    --------------------------------- ------ 24/29 [opentelemetry-sdk]
#    ---------------------------------- ----- 25/29 [databricks-sdk]
#    ---------------------------------- ----- 25/29 [databricks-sdk]
#    ---------------------------------- ----- 25/29 [databricks-sdk]
#    ---------------------------------- ----- 25/29 [databricks-sdk]
#    ---------------------------------- ----- 25/29 [databricks-sdk]
#    ---------------------------------- ----- 25/29 [databricks-sdk]
#    ---------------------------------- ----- 25/29 [databricks-sdk]
#    ---------------------------------- ----- 25/29 [databricks-sdk]
#    ---------------------------------- ----- 25/29 [databricks-sdk]
#    ---------------------------------- ----- 25/29 [databricks-sdk]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ----------------------------------- ---- 26/29 [mlflow-tracing]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    ------------------------------------- -- 27/29 [mlflow-skinny]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    -------------------------------------- - 28/29 [mlflow]
#    ---------------------------------------- 29/29 [mlflow]
#
# Successfully installed Flask-CORS-6.0.2 Mako-1.3.10 alembic-1.18.4 annotated-doc-0.0.4 databricks-sdk-0.96.0 docker-7.1.0 fastapi-0.135.1 google-auth-2.48.0 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 huey-2.6.0 mlflow-3.10.0 mlflow-skinny-3.10.0 mlflow-tracing-3.10.0 opentelemetry-api-1.39.1 opentelemetry-proto-1.39.1 opentelemetry-sdk-1.39.1 opentelemetry-semantic-conventions-0.60b1 pandas-2.3.3 prettytable-3.17.0 protobuf-6.33.5 rsa-4.9.1 skops-0.13.0 sqlparse-0.5.5 starlette-0.52.1 typing-inspection-0.4.2 uvicorn-0.41.0 waitress-3.0.2

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'sqlite:///C:/Users/Administrador.5198WortenAmo/OneDrive/Documentos/MBDS/MLOPS/MLOPS-NYC-TAXIS/03-experiment-tracking/mlflow.db'

# %%
mlflow.search_experiments()
# Out:
# 2026/03/03 17:18:21 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/03/03 17:18:21 INFO mlflow.store.db.utils: Updating database tables
# [<Experiment: artifact_location='file:c:/Users/Administrador.5198WortenAmo/OneDrive/Documentos/MBDS/MLOPS/MLOPS-NYC-TAXIS/03-experiment-tracking/mlruns/0', creation_time=1772554704741, experiment_id='0', last_update_time=1772554704741, lifecycle_stage='active', name='Default', tags={}, workspace='default'>]

# %% [markdown]
# ### Creating an experiment and logging a new run

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
import mlflow
import sklearn
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mlflow.set_experiment("my-experiment-1")

X, y = load_iris(return_X_y=True)
class_names = load_iris().target_names

models = [
    ("LogisticRegression", LogisticRegression(C=1.0, random_state=42, max_iter=1000, solver="lbfgs")),
    ("RandomForestClassifier", RandomForestClassifier(n_estimators=100, random_state=42))
]

for model_name, model in models:
    with mlflow.start_run() as run:
        mlflow.set_tag("model_type", model_name)
        mlflow.log_param("sklearn_version", sklearn.__version__)
        model.fit(X, y)
        y_pred = model.predict(X)
        acc = accuracy_score(y, y_pred)
        mlflow.log_metric("accuracy", acc)
        # Log confusion matrix as labeled DataFrame
        cm = confusion_matrix(y, y_pred)
        cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
        cm_df.to_csv("confusion_matrix_labeled.csv")
        mlflow.log_artifact("confusion_matrix_labeled.csv")
        # Confusion matrix heatmap as image
        plt.figure(figsize=(5,4))
        sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
        plt.title(f"Confusion Matrix ({model_name})")
        plt.ylabel("True label")
        plt.xlabel("Predicted label")
        plt.tight_layout()
        plt.savefig("confusion_matrix_heatmap.png")
        plt.close()
        mlflow.log_artifact("confusion_matrix_heatmap.png")
        # Provide input_example and use 'name' instead of deprecated 'artifact_path'
        input_example = np.expand_dims(X[0], axis=0)
        mlflow.sklearn.log_model(model, name="models", input_example=input_example)
        mlflow.set_tag("n_classes", len(np.unique(y)))
        mlflow.set_tag("run_time", datetime.datetime.now().isoformat())
        mlflow.set_tag("description", f"{model_name} on Iris dataset")
        print(f"Logged run for {model_name}, accuracy={acc:.3f}")
# Out:
# 2026/03/03 17:18:27 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# 2026/03/03 17:18:28 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Logged run for LogisticRegression, accuracy=0.973
# 2026/03/03 17:18:43 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Logged run for RandomForestClassifier, accuracy=1.000

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:c:/Users/Administrador.5198WortenAmo/OneDrive/Documentos/MBDS/MLOPS/MLOPS-NYC-TAXIS/03-experiment-tracking/mlruns/1', creation_time=1772554707813, experiment_id='1', last_update_time=1772554707813, lifecycle_stage='active', name='my-experiment-1', tags={}, workspace='default'>,
#  <Experiment: artifact_location='file:c:/Users/Administrador.5198WortenAmo/OneDrive/Documentos/MBDS/MLOPS/MLOPS-NYC-TAXIS/03-experiment-tracking/mlruns/0', creation_time=1772554704741, experiment_id='0', last_update_time=1772554704741, lifecycle_stage='active', name='Default', tags={}, workspace='default'>]

# %%
# Launch MLflow UI (default: uses local mlruns/ folder)
import subprocess
import sys

# This will run 'mlflow ui' as a background process
subprocess.Popen([sys.executable, '-m', 'mlflow', 'ui'])
print("MLflow UI started. Open http://localhost:5000 in your browser.")
# Out:
# MLflow UI started. Open http://localhost:5000 in your browser.

# %% [markdown]
# ### Interacting with the model registry

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient()

# %%
from mlflow.exceptions import MlflowException

try:
    client.search_registered_models()
except MlflowException:
    print("It's not possible to access the model registry :(")
